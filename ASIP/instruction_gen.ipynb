# %%
'''
    ASIP instruction generator
    [31:30] opcode (0~15):
        1: load
        2: dump
        3: ASIP exe
    [29:15] end_addr
    [14:0] start_addr
'''
import sys
sys.path.append(r"C:\Users\N26120579\Desktop\畢業光碟_蔡明翰\3.【系統資料】\Python\ASIP")
from ASIP_inst import ASIP_inst_gen, ASIP_txt_gen
from ASIP_inst import dec_to_bin_str, dec_to_hex_str

# %%
load_ifm0           = ASIP_inst_gen(opcode=1, start_addr=0x5000, choose_data_num=1, data_num=128)
load_ker0           = ASIP_inst_gen(opcode=1, start_addr=0x6000, choose_data_num=1, data_num=1115)
load_asip0          = ASIP_inst_gen(opcode=1, start_addr=0x0000, choose_data_num=1, data_num=4)
## asip inst data
write_dla_source    = ASIP_inst_gen(opcode=1, start_addr=0x7FF1, choose_data_num=0, end_addr=0x0000)
write_dla_target    = ASIP_inst_gen(opcode=1, start_addr=0x7FF2, choose_data_num=0, end_addr=0x0000)
write_dla_start     = ASIP_inst_gen(opcode=1, start_addr=0x7FF0, choose_data_num=0, end_addr=0x0001)
read_dla_end        = ASIP_inst_gen(opcode=2, start_addr=0x7FF3, choose_data_num=0, end_addr=0x0001)
##
load_dla0           = ASIP_inst_gen(opcode=1, start_addr=0x4000, choose_data_num=1, data_num=20)

print("load_ifm0:",     load_ifm0)
print("load_ker0:",     load_ker0)
print("load_asip0:",    load_asip0)

print("write_dla_source:",  write_dla_source)
print("write_dla_target:",  write_dla_target)
print("write_dla_start:",   write_dla_start)
print("read_dla_end:",      read_dla_end)

print("load_dla0:",     load_dla0)
# Out:
# load_ifm0: 683fd000
# load_ker0: 722d6000
# load_asip0: 40018000
# write_dla_source: 40007ff1
# write_dla_target: 40007ff2
# write_dla_start: 4000fff0
# read_dla_end: 8000fff3
# load_dla0: 6009c000

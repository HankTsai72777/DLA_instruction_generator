# %%
'''
    ASIP instruction generator
    [31:30] opcode (0~15):
        1: load
        2: dump
        3: ASIP exe
    [29:15] end_addr
    [14:0] start_addr
'''
import sys
sys.path.append(r"C:\Users\N26120579\Desktop\畢業光碟_蔡明翰\3.【系統資料】\Python\ASIP")
from ASIP_inst import ASIP_inst_gen, ASIP_txt_gen
from ASIP_inst import dec_to_bin_str, dec_to_hex_str

# %%
load_ifm = ASIP_inst_gen(opcode=1, start_addr=0x5000, choose_data_num=1, data_num=128)
print("load_ifm:", load_ifm)
load_ker = ASIP_inst_gen(opcode=1, start_addr=0x6000, choose_data_num=1, data_num=1115)
print("load_ifm:", load_ker)
# Out:
# load_ifm: 683fd000
# load_ifm: 722d6000

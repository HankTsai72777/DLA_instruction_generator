# %%
'''
    ASIP instruction generator
    [31:30] opcode (0~15):
        1: load
        2: dump
        3: ASIP exe
    [29:15] end_addr
    [14:0] start_addr
'''
import sys
sys.path.append(r"C:\Users\N26120579\Desktop\畢業光碟_蔡明翰\3.【系統資料】\Python\ASIP")
from ASIP_inst import ASIP_inst_gen, ASIP_txt_gen
from ASIP_inst import dec_to_bin_str, dec_to_hex_str

# %% [markdown]
# ## PCG

# %%
# load ifm data
load_ifm0           = ASIP_inst_gen(opcode=1, start_addr=0x5000, choose_data_num=1, data_num=135) # conv1
# load weight data
load_ker0           = ASIP_inst_gen(opcode=1, start_addr=0x6000, choose_data_num=1, data_num=8) # conv1
print("load_ifm0:               ", load_ifm0)
print("load_ker0:               ", load_ker0)
# Out:
# load_ifm0:                68435000
# load_ker0:                7003e000

# %% [markdown]
# ## ECG_v2

# %%
# load ifm data
load_ifm0           = ASIP_inst_gen(opcode=1, start_addr=0x5000, choose_data_num=1, data_num=128)

# load ker data
# load_ker0           = ASIP_inst_gen(opcode=1, start_addr=0x6000, choose_data_num=1, data_num=1115)
load_ker0           = ASIP_inst_gen(opcode=1, start_addr=0x6000, choose_data_num=1, data_num=1118) ## with conv 5 input

# load asip instdata
# load_asip0          = ASIP_inst_gen(opcode=1, start_addr=0x0000, choose_data_num=1, data_num=4)
load_asip0          = ASIP_inst_gen(opcode=1, start_addr=0x0000, choose_data_num=1, data_num=13) # dla, dma, dla

## asip inst data
# dla0
write_dla_source    = ASIP_inst_gen(opcode=1, start_addr=0x7FF1, choose_data_num=0, end_addr=0x0000)
#***<
# write_dla_target    = ASIP_inst_gen(opcode=1, start_addr=0x7FF2, choose_data_num=0, end_addr=0x0014) #20      # conv1
# write_dla_target    = ASIP_inst_gen(opcode=1, start_addr=0x7FF2, choose_data_num=0, end_addr=0x0028) #40      # conv2  p0
# write_dla_target    = ASIP_inst_gen(opcode=1, start_addr=0x7FF2, choose_data_num=0, end_addr=0x003C) #60      # conv2  p0 p1
# write_dla_target    = ASIP_inst_gen(opcode=1, start_addr=0x7FF2, choose_data_num=0, end_addr=0x0064) #100     # conv2
# write_dla_target    = ASIP_inst_gen(opcode=1, start_addr=0x7FF2, choose_data_num=0, end_addr=0x008C) #140     # conv3
write_dla_target    = ASIP_inst_gen(opcode=1, start_addr=0x7FF2, choose_data_num=0, end_addr=0x0094) #148     # conv4
#***>
write_dla_start     = ASIP_inst_gen(opcode=1, start_addr=0x7FF0, choose_data_num=0, end_addr=0x0001)
read_dla_end        = ASIP_inst_gen(opcode=2, start_addr=0x7FF3, choose_data_num=0, end_addr=0x0001)

# dma0
write_dma_source    = ASIP_inst_gen(opcode=1, start_addr=0x7FE1, choose_data_num=0, end_addr=0x645B) # 0x6000 + 1115(dec)
write_dma_target    = ASIP_inst_gen(opcode=1, start_addr=0x7FE2, choose_data_num=0, end_addr=0x5800) # ifm1
write_dma_last      = ASIP_inst_gen(opcode=1, start_addr=0x7FE3, choose_data_num=0, end_addr=0x5802)
write_dma_start     = ASIP_inst_gen(opcode=1, start_addr=0x7FE0, choose_data_num=0, end_addr=0x0001)
read_dma_end        = ASIP_inst_gen(opcode=2, start_addr=0x7FE4, choose_data_num=0, end_addr=0x0001)

# dla 1
write_dla_source_1  = ASIP_inst_gen(opcode=1, start_addr=0x7FF1, choose_data_num=0, end_addr=0x0094) # 148 # conv5
#***<
# write_dla_target_1  = ASIP_inst_gen(opcode=1, start_addr=0x7FF2, choose_data_num=0, end_addr=0x00A0) # 160 # conv5
# write_dla_target_1  = ASIP_inst_gen(opcode=1, start_addr=0x7FF2, choose_data_num=0, end_addr=0x00AE) # 174 # fc1
# write_dla_target_1  = ASIP_inst_gen(opcode=1, start_addr=0x7FF2, choose_data_num=0, end_addr=0x00B8) # 184 # fc2
write_dla_target_1  = ASIP_inst_gen(opcode=1, start_addr=0x7FF2, choose_data_num=0, end_addr=0x00C2) # 194 # fc3
#***>
write_dla_start_1   = ASIP_inst_gen(opcode=1, start_addr=0x7FF0, choose_data_num=0, end_addr=0x0001)
read_dla_end_1      = ASIP_inst_gen(opcode=2, start_addr=0x7FF3, choose_data_num=0, end_addr=0x0001)

## load dla inst
#***<
# load_dla0           = ASIP_inst_gen(opcode=1, start_addr=0x4000, choose_data_num=1, data_num=20)      # conv1
# load_dla0           = ASIP_inst_gen(opcode=1, start_addr=0x4000, choose_data_num=1, data_num=40)      # conv2 p0
# load_dla0           = ASIP_inst_gen(opcode=1, start_addr=0x4000, choose_data_num=1, data_num=60)      # conv2 p0 p1
# load_dla0           = ASIP_inst_gen(opcode=1, start_addr=0x4000, choose_data_num=1, data_num=100)     # conv2
# load_dla0           = ASIP_inst_gen(opcode=1, start_addr=0x4000, choose_data_num=1, data_num=140)     # conv3
# load_dla0           = ASIP_inst_gen(opcode=1, start_addr=0x4000, choose_data_num=1, data_num=148)     # conv4
# load_dla0           = ASIP_inst_gen(opcode=1, start_addr=0x4000, choose_data_num=1, data_num=160)     # conv5
# load_dla0           = ASIP_inst_gen(opcode=1, start_addr=0x4000, choose_data_num=1, data_num=174)     # fc1
# load_dla0           = ASIP_inst_gen(opcode=1, start_addr=0x4000, choose_data_num=1, data_num=184)     # fc2
load_dla0           = ASIP_inst_gen(opcode=1, start_addr=0x4000, choose_data_num=1, data_num=194)     # fc3
#***>

#***<
# exe_asip0           = ASIP_inst_gen(opcode=3, start_addr=0x0000, choose_data_num=1, data_num=4) # conv1~conv4
exe_asip0           = ASIP_inst_gen(opcode=3, start_addr=0x0000, choose_data_num=1, data_num=13) # conv1~fc3
#***>
dump_ofm0           = ASIP_inst_gen(opcode=2, start_addr=0x5800, choose_data_num=1, data_num=3)

print("load_ifm0:               ",      load_ifm0)
print("load_ker0:               ",      load_ker0)
print("load_asip0:              ",      load_asip0)
print("")
print("write_dla_source:        ",      write_dla_source)
print("write_dla_target **:     ",      write_dla_target)
print("write_dla_start:         ",      write_dla_start)
print("read_dla_end:            ",      read_dla_end)
print("")
print("write_dma_source         ",      write_dma_source)
print("write_dma_target         ",      write_dma_target)
print("write_dma_last           ",      write_dma_last  )
print("write_dma_start          ",      write_dma_start )
print("read_dma_end             ",      read_dma_end    )
print("")
print("write_dla_source_1:      ",      write_dla_source_1)
print("write_dla_target_1 ***:  ",      write_dla_target_1)
print("write_dla_start_1:       ",      write_dla_start_1)
print("read_dla_end_1:          ",      read_dla_end_1)
print("")
print("load_dla0 ***:           ",      load_dla0)
print("")
print("exe_asip0 *:             ",      exe_asip0)
print("")
print("dump_ofm0                :",     dump_ofm0)
# Out:
# load_ifm0:                683fd000
# load_ker0:                722ee000
# load_asip0:               40060000
#
# write_dla_source:         40007ff1
# write_dla_target **:      404a7ff2
# write_dla_start:          4000fff0
# read_dla_end:             8000fff3
#
# write_dma_source          722dffe1
# write_dma_target          6c007fe2
# write_dma_last            6c017fe3
# write_dma_start           4000ffe0
# read_dma_end              8000ffe4
#
# write_dla_source_1:       404a7ff1
# write_dla_target_1 ***:   40617ff2
# write_dla_start_1:        4000fff0
# read_dla_end_1:           8000fff3
#
# load_dla0 ***:            6060c000
#
# exe_asip0 *:              c0060000
#
# dump_ofm0                : ac015800

# %% [markdown]
# ## ECG rhythmn

# %% [markdown]
# ## SPI test

# %%
# spi 0 program
load_ifm0           = ASIP_inst_gen(opcode=1, start_addr=0x5000, choose_data_num=1, data_num=3)
dump_ifm0           = ASIP_inst_gen(opcode=2, start_addr=0x5000, choose_data_num=1, data_num=3)
load_ifm1           = ASIP_inst_gen(opcode=1, start_addr=0x5800, choose_data_num=1, data_num=3)
dump_ifm1           = ASIP_inst_gen(opcode=2, start_addr=0x5800, choose_data_num=1, data_num=3)

print("load_ifm0:               ",      load_ifm0)
print("dump_ifm0:               ",      dump_ifm0)
print("load_ifm1:               ",      load_ifm1)
print("dump_ifm1:               ",      dump_ifm1)
# Out:
# load_ifm0:                68015000
# dump_ifm0:                a8015000
# load_ifm1:                6c015800
# dump_ifm1:                ac015800

# %% [markdown]
# ## VSD PROG

# %%
# load riscv inst
load_im_data_0      = ASIP_inst_gen(opcode=1, start_addr=0x2000, choose_data_num=1, data_num=165)
load_dm_data_0      = ASIP_inst_gen(opcode=1, start_addr=0x30A5, choose_data_num=1, data_num=2)

load_asip_data_0    = ASIP_inst_gen(opcode=1, start_addr=0x0000, choose_data_num=1, data_num=4)

write_cpu_source    = ASIP_inst_gen(opcode=1, start_addr=0x7FD1, choose_data_num=0, end_addr=0x0000)
write_cpu_target    = ASIP_inst_gen(opcode=1, start_addr=0x7FD2, choose_data_num=0, end_addr=0x47ff)
write_cpu_start     = ASIP_inst_gen(opcode=1, start_addr=0x7FD0, choose_data_num=0, end_addr=0x0001)
read_cpu_finish     = ASIP_inst_gen(opcode=2, start_addr=0x7FD3, choose_data_num=0, end_addr=0x0001)

exe_asip0           = ASIP_inst_gen(opcode=3, start_addr=0x0000, choose_data_num=1, data_num=4)

print("load_im_data_0   :", load_im_data_0)
print("load_dm_data_0   :", load_dm_data_0)
print("")
print("load_asip_data_0 :", load_asip_data_0)
print("")
print("write_cpu_source :", write_cpu_source)
print("write_cpu_target :", write_cpu_target)
print("write_cpu_start  :", write_cpu_start )
print("read_cpu_finish  :", read_cpu_finish )
print("")
print("exe_asip0        :", exe_asip0)
# Out:
# load_im_data_0   : 50522000
# load_dm_data_0   : 585330a5
#
# load_asip_data_0 : 40018000
#
# write_cpu_source : 40007fd1
# write_cpu_target : 63ffffd2
# write_cpu_start  : 4000ffd0
# read_cpu_finish  : 8000ffd3
#
# exe_asip0        : c0018000

# %% [markdown]
# ### VSD PROG0

# %%
# System instructuin
load_CPU_IM0        =   ASIP_inst_gen(opcode=1, start_addr=0x2000, choose_data_num=1, data_num=777)
# Exe instruction
load_ASIP_IM0       =   ASIP_inst_gen(opcode=1, start_addr=0x0000, choose_data_num=1, data_num=4)
write_cpu_source    =   ASIP_inst_gen(opcode=1, start_addr=0x7FD1, choose_data_num=0, end_addr=0x0000)
write_cpu_target    =   ASIP_inst_gen(opcode=1, start_addr=0x7FD2, choose_data_num=0, end_addr=0x43FF)
write_cpu_start     =   ASIP_inst_gen(opcode=1, start_addr=0x7FD0, choose_data_num=0, end_addr=0x0001)
read_cpu_finish     =   ASIP_inst_gen(opcode=2, start_addr=0x7FD3, choose_data_num=0, end_addr=0x0001)

exe_asip0           =   ASIP_inst_gen(opcode=3, start_addr=0x0000, choose_data_num=1, data_num=4)

dump_CPU_DM0        =   ASIP_inst_gen(opcode=2, start_addr=0x3000, choose_data_num=1, data_num=51)

print("load_CPU_IM0         ", load_CPU_IM0)
print("load_ASIP_IM0        ", load_ASIP_IM0)

print("write_cpu_source     ", write_cpu_source)
print("write_cpu_target     ", write_cpu_target)
print("write_cpu_start      ", write_cpu_start)
print("read_cpu_finish      ", read_cpu_finish)

print("exe_asip0            ", exe_asip0)

print("dump_CPU_DM0         ", dump_CPU_DM0)
# Out:
# load_CPU_IM0          51842000
# load_ASIP_IM0         40018000
# write_cpu_source      40007fd1
# write_cpu_target      61ffffd2
# write_cpu_start       4000ffd0
# read_cpu_finish       8000ffd3
# exe_asip0             c0018000
# dump_CPU_DM0          98193000

# %% [markdown]
# ### VSD PROG1

# %%
# System instructuin
load_CPU_IM0        =   ASIP_inst_gen(opcode=1, start_addr=0x2000, choose_data_num=1, data_num=189)
# Exe instruction
load_ASIP_IM0       =   ASIP_inst_gen(opcode=1, start_addr=0x0000, choose_data_num=1, data_num=4)
write_cpu_source    =   ASIP_inst_gen(opcode=1, start_addr=0x7FD1, choose_data_num=0, end_addr=0x0000)
write_cpu_target    =   ASIP_inst_gen(opcode=1, start_addr=0x7FD2, choose_data_num=0, end_addr=0x43FF)
write_cpu_start     =   ASIP_inst_gen(opcode=1, start_addr=0x7FD0, choose_data_num=0, end_addr=0x0001)
read_cpu_finish     =   ASIP_inst_gen(opcode=2, start_addr=0x7FD3, choose_data_num=0, end_addr=0x0001)

exe_asip0           =   ASIP_inst_gen(opcode=3, start_addr=0x0000, choose_data_num=1, data_num=4)

dump_CPU_DM0        =   ASIP_inst_gen(opcode=2, start_addr=0x3000, choose_data_num=1, data_num=32)

print("load_CPU_IM0         ", load_CPU_IM0)
print("load_ASIP_IM0        ", load_ASIP_IM0)

print("write_cpu_source     ", write_cpu_source)
print("write_cpu_target     ", write_cpu_target)
print("write_cpu_start      ", write_cpu_start)
print("read_cpu_finish      ", read_cpu_finish)

print("exe_asip0            ", exe_asip0)

print("dump_CPU_DM0         ", dump_CPU_DM0)
# Out:
# load_CPU_IM0          505e2000
# load_ASIP_IM0         40018000
# write_cpu_source      40007fd1
# write_cpu_target      61ffffd2
# write_cpu_start       4000ffd0
# read_cpu_finish       8000ffd3
# exe_asip0             c0018000
# dump_CPU_DM0          980fb000

# %% [markdown]
# ### VSD PROG2

# %%
# System instructuin
load_CPU_IM0        =   ASIP_inst_gen(opcode=1, start_addr=0x2000, choose_data_num=1, data_num=141)
# Exe instruction
load_ASIP_IM0       =   ASIP_inst_gen(opcode=1, start_addr=0x0000, choose_data_num=1, data_num=4)
write_cpu_source    =   ASIP_inst_gen(opcode=1, start_addr=0x7FD1, choose_data_num=0, end_addr=0x0000)
write_cpu_target    =   ASIP_inst_gen(opcode=1, start_addr=0x7FD2, choose_data_num=0, end_addr=0x43FF)
write_cpu_start     =   ASIP_inst_gen(opcode=1, start_addr=0x7FD0, choose_data_num=0, end_addr=0x0001)
read_cpu_finish     =   ASIP_inst_gen(opcode=2, start_addr=0x7FD3, choose_data_num=0, end_addr=0x0001)

exe_asip0           =   ASIP_inst_gen(opcode=3, start_addr=0x0000, choose_data_num=1, data_num=4)

dump_CPU_DM0        =   ASIP_inst_gen(opcode=2, start_addr=0x3000, choose_data_num=1, data_num=2)

print("load_CPU_IM0         ", load_CPU_IM0)
print("load_ASIP_IM0        ", load_ASIP_IM0)

print("write_cpu_source     ", write_cpu_source)
print("write_cpu_target     ", write_cpu_target)
print("write_cpu_start      ", write_cpu_start)
print("read_cpu_finish      ", read_cpu_finish)

print("exe_asip0            ", exe_asip0)

print("dump_CPU_DM0         ", dump_CPU_DM0)
# Out:
# load_CPU_IM0          50462000
# load_ASIP_IM0         40018000
# write_cpu_source      40007fd1
# write_cpu_target      61ffffd2
# write_cpu_start       4000ffd0
# read_cpu_finish       8000ffd3
# exe_asip0             c0018000
# dump_CPU_DM0          9800b000

# %% [markdown]
# ### VSD PROG3

# %%
# System instructuin
load_CPU_IM0        =   ASIP_inst_gen(opcode=1, start_addr=0x2000, choose_data_num=1, data_num=167)
# Exe instruction
load_ASIP_IM0       =   ASIP_inst_gen(opcode=1, start_addr=0x0000, choose_data_num=1, data_num=4)
write_cpu_source    =   ASIP_inst_gen(opcode=1, start_addr=0x7FD1, choose_data_num=0, end_addr=0x0000)
write_cpu_target    =   ASIP_inst_gen(opcode=1, start_addr=0x7FD2, choose_data_num=0, end_addr=0x43FF)
write_cpu_start     =   ASIP_inst_gen(opcode=1, start_addr=0x7FD0, choose_data_num=0, end_addr=0x0001)
read_cpu_finish     =   ASIP_inst_gen(opcode=2, start_addr=0x7FD3, choose_data_num=0, end_addr=0x0001)

exe_asip0           =   ASIP_inst_gen(opcode=3, start_addr=0x0000, choose_data_num=1, data_num=4)

dump_CPU_DM0        =   ASIP_inst_gen(opcode=2, start_addr=0x3000, choose_data_num=1, data_num=1)

print("load_CPU_IM0         ", load_CPU_IM0)
print("load_ASIP_IM0        ", load_ASIP_IM0)

print("write_cpu_source     ", write_cpu_source)
print("write_cpu_target     ", write_cpu_target)
print("write_cpu_start      ", write_cpu_start)
print("read_cpu_finish      ", read_cpu_finish)

print("exe_asip0            ", exe_asip0)

print("dump_CPU_DM0         ", dump_CPU_DM0)
# Out:
# load_CPU_IM0          50532000
# load_ASIP_IM0         40018000
# write_cpu_source      40007fd1
# write_cpu_target      61ffffd2
# write_cpu_start       4000ffd0
# read_cpu_finish       8000ffd3
# exe_asip0             c0018000
# dump_CPU_DM0          98003000

# %% [markdown]
# ### VSD PROG4

# %%
# System instructuin
load_CPU_IM0        =   ASIP_inst_gen(opcode=1, start_addr=0x2000, choose_data_num=1, data_num=138)
# Exe instruction
load_ASIP_IM0       =   ASIP_inst_gen(opcode=1, start_addr=0x0000, choose_data_num=1, data_num=4)
write_cpu_source    =   ASIP_inst_gen(opcode=1, start_addr=0x7FD1, choose_data_num=0, end_addr=0x0000)
write_cpu_target    =   ASIP_inst_gen(opcode=1, start_addr=0x7FD2, choose_data_num=0, end_addr=0x43FF)
write_cpu_start     =   ASIP_inst_gen(opcode=1, start_addr=0x7FD0, choose_data_num=0, end_addr=0x0001)
read_cpu_finish     =   ASIP_inst_gen(opcode=2, start_addr=0x7FD3, choose_data_num=0, end_addr=0x0001)

exe_asip0           =   ASIP_inst_gen(opcode=3, start_addr=0x0000, choose_data_num=1, data_num=4)

dump_CPU_DM0        =   ASIP_inst_gen(opcode=2, start_addr=0x3000, choose_data_num=1, data_num=3)

print("load_CPU_IM0         ", load_CPU_IM0)
print("load_ASIP_IM0        ", load_ASIP_IM0)

print("write_cpu_source     ", write_cpu_source)
print("write_cpu_target     ", write_cpu_target)
print("write_cpu_start      ", write_cpu_start)
print("read_cpu_finish      ", read_cpu_finish)

print("exe_asip0            ", exe_asip0)

print("dump_CPU_DM0         ", dump_CPU_DM0)
# Out:
# load_CPU_IM0          5044a000
# load_ASIP_IM0         40018000
# write_cpu_source      40007fd1
# write_cpu_target      61ffffd2
# write_cpu_start       4000ffd0
# read_cpu_finish       8000ffd3
# exe_asip0             c0018000
# dump_CPU_DM0          98013000

# %% [markdown]
# ### VSD PROG5

# %%
# System instructuin
load_CPU_IM0        =   ASIP_inst_gen(opcode=1, start_addr=0x2000, choose_data_num=1, data_num=119)
# Exe instruction
load_ASIP_IM0       =   ASIP_inst_gen(opcode=1, start_addr=0x0000, choose_data_num=1, data_num=4)
write_cpu_source    =   ASIP_inst_gen(opcode=1, start_addr=0x7FD1, choose_data_num=0, end_addr=0x0000)
write_cpu_target    =   ASIP_inst_gen(opcode=1, start_addr=0x7FD2, choose_data_num=0, end_addr=0x43FF)
write_cpu_start     =   ASIP_inst_gen(opcode=1, start_addr=0x7FD0, choose_data_num=0, end_addr=0x0001)
read_cpu_finish     =   ASIP_inst_gen(opcode=2, start_addr=0x7FD3, choose_data_num=0, end_addr=0x0001)

exe_asip0           =   ASIP_inst_gen(opcode=3, start_addr=0x0000, choose_data_num=1, data_num=4)

dump_CPU_DM0        =   ASIP_inst_gen(opcode=2, start_addr=0x3000, choose_data_num=1, data_num=4)

print("load_CPU_IM0         ", load_CPU_IM0)
print("load_ASIP_IM0        ", load_ASIP_IM0)

print("write_cpu_source     ", write_cpu_source)
print("write_cpu_target     ", write_cpu_target)
print("write_cpu_start      ", write_cpu_start)
print("read_cpu_finish      ", read_cpu_finish)

print("exe_asip0            ", exe_asip0)

print("dump_CPU_DM0         ", dump_CPU_DM0)
# Out:
# load_CPU_IM0          503b2000
# load_ASIP_IM0         40018000
# write_cpu_source      40007fd1
# write_cpu_target      61ffffd2
# write_cpu_start       4000ffd0
# read_cpu_finish       8000ffd3
# exe_asip0             c0018000
# dump_CPU_DM0          9801b000
